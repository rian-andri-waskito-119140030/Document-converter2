# %%
import cv2
import numpy as np
import os

# %%
def urutkan_titik(pts):
    """Urutkan titik jadi [Top-Left, Top-Right, Bottom-Right, Bottom-Left]"""
    rect = np.zeros((4, 2), dtype="float32")
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]   # top-left
    rect[2] = pts[np.argmax(s)]   # bottom-right
    diff = np.diff(pts, axis=1)
    rect[1] = pts[np.argmin(diff)]  # top-right
    rect[3] = pts[np.argmax(diff)]  # bottom-left
    return rect

# %%
def four_point_transform(image, pts):
    """Lakukan transformasi perspektif"""
    rect = urutkan_titik(pts)
    (tl, tr, br, bl) = rect
    widthA = np.linalg.norm(br - bl)
    widthB = np.linalg.norm(tr - tl)
    maxWidth = max(int(widthA), int(widthB))
    heightA = np.linalg.norm(tr - br)
    heightB = np.linalg.norm(tl - bl)
    maxHeight = max(int(heightA), int(heightB))
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")
    M = cv2.getPerspectiveTransform(rect, dst)
    warp = cv2.warpPerspective(image, M, (maxWidth, maxHeight))
    return warp

# %%
def proses_gambar(path_input, path_output):
    image = cv2.imread(path_input)
    if image is None:
        print(f"Gagal membaca gambar: {path_input}")
        return

    nama_file = os.path.splitext(os.path.basename(path_input))[0]

    orig = image.copy()
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Deteksi tepi
    edged = cv2.Canny(gray, 75, 200)

    # Temukan kontur
    contours, _ = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:5]

    doc_cnt = None
    for c in contours:
        peri = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.02 * peri, True)
        if len(approx) == 4:
            doc_cnt = approx.reshape(4, 2)
            break

    if doc_cnt is None:
        print(f"❌ Dokumen tidak ditemukan pada {nama_file}")
        return

    rect = urutkan_titik(doc_cnt)
    labels = ["TL", "TR", "BR", "BL"]

    # Gambar titik koordinat
    for i, (x, y) in enumerate(rect):
        x, y = int(x), int(y)
        cv2.circle(image, (x, y), 8, (0, 0, 255), -1)
        teks = f"{labels[i]} ({x},{y})"
        cv2.putText(image, teks, (x + 10, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (255, 255, 255), 2, cv2.LINE_AA)
        cv2.putText(image, teks, (x + 10, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 0, 0), 1, cv2.LINE_AA)

    # Gambar garis antar titik
    pts = rect.astype(int)
    cv2.polylines(image, [pts], isClosed=True, color=(0, 255, 0), thickness=2)

    # Simpan hasil anotasi
    output_annotated = os.path.join(path_output, f"{nama_file}_annotated.jpg")
    cv2.imwrite(output_annotated, image)
    print(f"✅ {nama_file}: Gambar dengan koordinat disimpan di {output_annotated}")

    # Tampilkan hasil
    cv2.imshow("Koordinat Dokumen", image)
    cv2.waitKey(500)  # tampil 0.5 detik per gambar

    # Transformasi perspektif (scan)
    warped = four_point_transform(orig, rect)
    warped_gray = cv2.cvtColor(warped, cv2.COLOR_BGR2GRAY)
    warped_clean = cv2.adaptiveThreshold(
        warped_gray, 255,
        cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 15, 10
    )

    output_scan = os.path.join(path_output, f"{nama_file}_scan.jpg")
    cv2.imwrite(output_scan, warped_clean)
    print(f"🧾 {nama_file}: Hasil scan bersih disimpan di {output_scan}\n")

# %%
def main():
    folder_input = "data_mentah"
    folder_output = "data_output"

    if not os.path.exists(folder_output):
        os.makedirs(folder_output)

    file_list = [f for f in os.listdir(folder_input)
                 if f.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tiff'))]

    if not file_list:
        print("❌ Tidak ada gambar di folder data_mentah/")
        return

    for file_name in file_list:
        path_in = os.path.join(folder_input, file_name)
        proses_gambar(path_in, folder_output)

    cv2.destroyAllWindows()
    print("🚀 Semua gambar selesai diproses!")

if __name__ == "__main__":
    main()
# Out:
# ✅ data_a1: Gambar dengan koordinat disimpan di data_output\data_a1_annotated.jpg
# 🧾 data_a1: Hasil scan bersih disimpan di data_output\data_a1_scan.jpg
#
# ✅ data_a10: Gambar dengan koordinat disimpan di data_output\data_a10_annotated.jpg
# 🧾 data_a10: Hasil scan bersih disimpan di data_output\data_a10_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a100
# ✅ data_a101: Gambar dengan koordinat disimpan di data_output\data_a101_annotated.jpg
# 🧾 data_a101: Hasil scan bersih disimpan di data_output\data_a101_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a102
# ❌ Dokumen tidak ditemukan pada data_a103
# ✅ data_a104: Gambar dengan koordinat disimpan di data_output\data_a104_annotated.jpg
# 🧾 data_a104: Hasil scan bersih disimpan di data_output\data_a104_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a105
# ❌ Dokumen tidak ditemukan pada data_a107
# ❌ Dokumen tidak ditemukan pada data_a108
# ❌ Dokumen tidak ditemukan pada data_a109
# ✅ data_a11: Gambar dengan koordinat disimpan di data_output\data_a11_annotated.jpg
# 🧾 data_a11: Hasil scan bersih disimpan di data_output\data_a11_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a110
# ✅ data_a111: Gambar dengan koordinat disimpan di data_output\data_a111_annotated.jpg
# 🧾 data_a111: Hasil scan bersih disimpan di data_output\data_a111_scan.jpg
#
# ✅ data_a112: Gambar dengan koordinat disimpan di data_output\data_a112_annotated.jpg
# 🧾 data_a112: Hasil scan bersih disimpan di data_output\data_a112_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a113
# ✅ data_a114: Gambar dengan koordinat disimpan di data_output\data_a114_annotated.jpg
# 🧾 data_a114: Hasil scan bersih disimpan di data_output\data_a114_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a115
# ❌ Dokumen tidak ditemukan pada data_a116
# ❌ Dokumen tidak ditemukan pada data_a117
# ✅ data_a118: Gambar dengan koordinat disimpan di data_output\data_a118_annotated.jpg
# 🧾 data_a118: Hasil scan bersih disimpan di data_output\data_a118_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a119
# ✅ data_a12: Gambar dengan koordinat disimpan di data_output\data_a12_annotated.jpg
# 🧾 data_a12: Hasil scan bersih disimpan di data_output\data_a12_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a120
# ✅ data_a121: Gambar dengan koordinat disimpan di data_output\data_a121_annotated.jpg
# 🧾 data_a121: Hasil scan bersih disimpan di data_output\data_a121_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a122
# ✅ data_a123: Gambar dengan koordinat disimpan di data_output\data_a123_annotated.jpg
# 🧾 data_a123: Hasil scan bersih disimpan di data_output\data_a123_scan.jpg
#
# ✅ data_a124: Gambar dengan koordinat disimpan di data_output\data_a124_annotated.jpg
# 🧾 data_a124: Hasil scan bersih disimpan di data_output\data_a124_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a125
# ✅ data_a126: Gambar dengan koordinat disimpan di data_output\data_a126_annotated.jpg
# 🧾 data_a126: Hasil scan bersih disimpan di data_output\data_a126_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a127
# ❌ Dokumen tidak ditemukan pada data_a128
# ✅ data_a129: Gambar dengan koordinat disimpan di data_output\data_a129_annotated.jpg
# 🧾 data_a129: Hasil scan bersih disimpan di data_output\data_a129_scan.jpg
#
# ✅ data_a13: Gambar dengan koordinat disimpan di data_output\data_a13_annotated.jpg
# 🧾 data_a13: Hasil scan bersih disimpan di data_output\data_a13_scan.jpg
#
# ✅ data_a130: Gambar dengan koordinat disimpan di data_output\data_a130_annotated.jpg
# 🧾 data_a130: Hasil scan bersih disimpan di data_output\data_a130_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a131
# ❌ Dokumen tidak ditemukan pada data_a132
# ✅ data_a133: Gambar dengan koordinat disimpan di data_output\data_a133_annotated.jpg
# 🧾 data_a133: Hasil scan bersih disimpan di data_output\data_a133_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a134
# ❌ Dokumen tidak ditemukan pada data_a135
# ✅ data_a136: Gambar dengan koordinat disimpan di data_output\data_a136_annotated.jpg
# 🧾 data_a136: Hasil scan bersih disimpan di data_output\data_a136_scan.jpg
#
# ✅ data_a137: Gambar dengan koordinat disimpan di data_output\data_a137_annotated.jpg
# 🧾 data_a137: Hasil scan bersih disimpan di data_output\data_a137_scan.jpg
#
# ✅ data_a138: Gambar dengan koordinat disimpan di data_output\data_a138_annotated.jpg
# 🧾 data_a138: Hasil scan bersih disimpan di data_output\data_a138_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a139
# ✅ data_a14: Gambar dengan koordinat disimpan di data_output\data_a14_annotated.jpg
# 🧾 data_a14: Hasil scan bersih disimpan di data_output\data_a14_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a140
# ✅ data_a141: Gambar dengan koordinat disimpan di data_output\data_a141_annotated.jpg
# 🧾 data_a141: Hasil scan bersih disimpan di data_output\data_a141_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a142
# ✅ data_a143: Gambar dengan koordinat disimpan di data_output\data_a143_annotated.jpg
# 🧾 data_a143: Hasil scan bersih disimpan di data_output\data_a143_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a144
# ✅ data_a145: Gambar dengan koordinat disimpan di data_output\data_a145_annotated.jpg
# 🧾 data_a145: Hasil scan bersih disimpan di data_output\data_a145_scan.jpg
#
# ✅ data_a146: Gambar dengan koordinat disimpan di data_output\data_a146_annotated.jpg
# 🧾 data_a146: Hasil scan bersih disimpan di data_output\data_a146_scan.jpg
#
# ✅ data_a147: Gambar dengan koordinat disimpan di data_output\data_a147_annotated.jpg
# 🧾 data_a147: Hasil scan bersih disimpan di data_output\data_a147_scan.jpg
#
# ✅ data_a148: Gambar dengan koordinat disimpan di data_output\data_a148_annotated.jpg
# 🧾 data_a148: Hasil scan bersih disimpan di data_output\data_a148_scan.jpg
#
# ✅ data_a149: Gambar dengan koordinat disimpan di data_output\data_a149_annotated.jpg
# 🧾 data_a149: Hasil scan bersih disimpan di data_output\data_a149_scan.jpg
#
# ✅ data_a15: Gambar dengan koordinat disimpan di data_output\data_a15_annotated.jpg
# 🧾 data_a15: Hasil scan bersih disimpan di data_output\data_a15_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a150
# ❌ Dokumen tidak ditemukan pada data_a151
# ✅ data_a152: Gambar dengan koordinat disimpan di data_output\data_a152_annotated.jpg
# 🧾 data_a152: Hasil scan bersih disimpan di data_output\data_a152_scan.jpg
#
# ✅ data_a153: Gambar dengan koordinat disimpan di data_output\data_a153_annotated.jpg
# 🧾 data_a153: Hasil scan bersih disimpan di data_output\data_a153_scan.jpg
#
# ✅ data_a154: Gambar dengan koordinat disimpan di data_output\data_a154_annotated.jpg
# 🧾 data_a154: Hasil scan bersih disimpan di data_output\data_a154_scan.jpg
#
# ✅ data_a155: Gambar dengan koordinat disimpan di data_output\data_a155_annotated.jpg
# 🧾 data_a155: Hasil scan bersih disimpan di data_output\data_a155_scan.jpg
#
# ✅ data_a156: Gambar dengan koordinat disimpan di data_output\data_a156_annotated.jpg
# 🧾 data_a156: Hasil scan bersih disimpan di data_output\data_a156_scan.jpg
#
# ✅ data_a157: Gambar dengan koordinat disimpan di data_output\data_a157_annotated.jpg
# 🧾 data_a157: Hasil scan bersih disimpan di data_output\data_a157_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a158
# ✅ data_a159: Gambar dengan koordinat disimpan di data_output\data_a159_annotated.jpg
# 🧾 data_a159: Hasil scan bersih disimpan di data_output\data_a159_scan.jpg
#
# ✅ data_a16: Gambar dengan koordinat disimpan di data_output\data_a16_annotated.jpg
# 🧾 data_a16: Hasil scan bersih disimpan di data_output\data_a16_scan.jpg
#
# ✅ data_a160: Gambar dengan koordinat disimpan di data_output\data_a160_annotated.jpg
# 🧾 data_a160: Hasil scan bersih disimpan di data_output\data_a160_scan.jpg
#
# ✅ data_a161: Gambar dengan koordinat disimpan di data_output\data_a161_annotated.jpg
# 🧾 data_a161: Hasil scan bersih disimpan di data_output\data_a161_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a162
# ❌ Dokumen tidak ditemukan pada data_a163
# ✅ data_a164: Gambar dengan koordinat disimpan di data_output\data_a164_annotated.jpg
# 🧾 data_a164: Hasil scan bersih disimpan di data_output\data_a164_scan.jpg
#
# ✅ data_a165: Gambar dengan koordinat disimpan di data_output\data_a165_annotated.jpg
# 🧾 data_a165: Hasil scan bersih disimpan di data_output\data_a165_scan.jpg
#
# ✅ data_a166: Gambar dengan koordinat disimpan di data_output\data_a166_annotated.jpg
# 🧾 data_a166: Hasil scan bersih disimpan di data_output\data_a166_scan.jpg
#
# ✅ data_a167: Gambar dengan koordinat disimpan di data_output\data_a167_annotated.jpg
# 🧾 data_a167: Hasil scan bersih disimpan di data_output\data_a167_scan.jpg
#
# ✅ data_a168: Gambar dengan koordinat disimpan di data_output\data_a168_annotated.jpg
# 🧾 data_a168: Hasil scan bersih disimpan di data_output\data_a168_scan.jpg
#
# ✅ data_a169: Gambar dengan koordinat disimpan di data_output\data_a169_annotated.jpg
# 🧾 data_a169: Hasil scan bersih disimpan di data_output\data_a169_scan.jpg
#
# ✅ data_a17: Gambar dengan koordinat disimpan di data_output\data_a17_annotated.jpg
# 🧾 data_a17: Hasil scan bersih disimpan di data_output\data_a17_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a170
# ✅ data_a171: Gambar dengan koordinat disimpan di data_output\data_a171_annotated.jpg
# 🧾 data_a171: Hasil scan bersih disimpan di data_output\data_a171_scan.jpg
#
# ✅ data_a172: Gambar dengan koordinat disimpan di data_output\data_a172_annotated.jpg
# 🧾 data_a172: Hasil scan bersih disimpan di data_output\data_a172_scan.jpg
#
# ✅ data_a173: Gambar dengan koordinat disimpan di data_output\data_a173_annotated.jpg
# 🧾 data_a173: Hasil scan bersih disimpan di data_output\data_a173_scan.jpg
#
# ✅ data_a174: Gambar dengan koordinat disimpan di data_output\data_a174_annotated.jpg
# 🧾 data_a174: Hasil scan bersih disimpan di data_output\data_a174_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a175
# ✅ data_a176: Gambar dengan koordinat disimpan di data_output\data_a176_annotated.jpg
# 🧾 data_a176: Hasil scan bersih disimpan di data_output\data_a176_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a177
# ❌ Dokumen tidak ditemukan pada data_a178
# ✅ data_a179: Gambar dengan koordinat disimpan di data_output\data_a179_annotated.jpg
# 🧾 data_a179: Hasil scan bersih disimpan di data_output\data_a179_scan.jpg
#
# ✅ data_a18: Gambar dengan koordinat disimpan di data_output\data_a18_annotated.jpg
# 🧾 data_a18: Hasil scan bersih disimpan di data_output\data_a18_scan.jpg
#
# ✅ data_a180: Gambar dengan koordinat disimpan di data_output\data_a180_annotated.jpg
# 🧾 data_a180: Hasil scan bersih disimpan di data_output\data_a180_scan.jpg
#
# ✅ data_a181: Gambar dengan koordinat disimpan di data_output\data_a181_annotated.jpg
# 🧾 data_a181: Hasil scan bersih disimpan di data_output\data_a181_scan.jpg
#
# ✅ data_a182: Gambar dengan koordinat disimpan di data_output\data_a182_annotated.jpg
# 🧾 data_a182: Hasil scan bersih disimpan di data_output\data_a182_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a183
# ✅ data_a184: Gambar dengan koordinat disimpan di data_output\data_a184_annotated.jpg
# 🧾 data_a184: Hasil scan bersih disimpan di data_output\data_a184_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a185
# ✅ data_a186: Gambar dengan koordinat disimpan di data_output\data_a186_annotated.jpg
# 🧾 data_a186: Hasil scan bersih disimpan di data_output\data_a186_scan.jpg
#
# ✅ data_a187: Gambar dengan koordinat disimpan di data_output\data_a187_annotated.jpg
# 🧾 data_a187: Hasil scan bersih disimpan di data_output\data_a187_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a188
# ✅ data_a189: Gambar dengan koordinat disimpan di data_output\data_a189_annotated.jpg
# 🧾 data_a189: Hasil scan bersih disimpan di data_output\data_a189_scan.jpg
#
# ✅ data_a19: Gambar dengan koordinat disimpan di data_output\data_a19_annotated.jpg
# 🧾 data_a19: Hasil scan bersih disimpan di data_output\data_a19_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a190
# ✅ data_a191: Gambar dengan koordinat disimpan di data_output\data_a191_annotated.jpg
# 🧾 data_a191: Hasil scan bersih disimpan di data_output\data_a191_scan.jpg
#
# ✅ data_a192: Gambar dengan koordinat disimpan di data_output\data_a192_annotated.jpg
# 🧾 data_a192: Hasil scan bersih disimpan di data_output\data_a192_scan.jpg
#
# ✅ data_a193: Gambar dengan koordinat disimpan di data_output\data_a193_annotated.jpg
# 🧾 data_a193: Hasil scan bersih disimpan di data_output\data_a193_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a194
# ✅ data_a195: Gambar dengan koordinat disimpan di data_output\data_a195_annotated.jpg
# 🧾 data_a195: Hasil scan bersih disimpan di data_output\data_a195_scan.jpg
#
# ✅ data_a196: Gambar dengan koordinat disimpan di data_output\data_a196_annotated.jpg
# 🧾 data_a196: Hasil scan bersih disimpan di data_output\data_a196_scan.jpg
#
# ✅ data_a197: Gambar dengan koordinat disimpan di data_output\data_a197_annotated.jpg
# 🧾 data_a197: Hasil scan bersih disimpan di data_output\data_a197_scan.jpg
#
# ✅ data_a198: Gambar dengan koordinat disimpan di data_output\data_a198_annotated.jpg
# 🧾 data_a198: Hasil scan bersih disimpan di data_output\data_a198_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a199
# ✅ data_a2: Gambar dengan koordinat disimpan di data_output\data_a2_annotated.jpg
# 🧾 data_a2: Hasil scan bersih disimpan di data_output\data_a2_scan.jpg
#
# ✅ data_a20: Gambar dengan koordinat disimpan di data_output\data_a20_annotated.jpg
# 🧾 data_a20: Hasil scan bersih disimpan di data_output\data_a20_scan.jpg
#
# ✅ data_a200: Gambar dengan koordinat disimpan di data_output\data_a200_annotated.jpg
# 🧾 data_a200: Hasil scan bersih disimpan di data_output\data_a200_scan.jpg
#
# ✅ data_a201: Gambar dengan koordinat disimpan di data_output\data_a201_annotated.jpg
# 🧾 data_a201: Hasil scan bersih disimpan di data_output\data_a201_scan.jpg
#
# ✅ data_a202: Gambar dengan koordinat disimpan di data_output\data_a202_annotated.jpg
# 🧾 data_a202: Hasil scan bersih disimpan di data_output\data_a202_scan.jpg
#
# ✅ data_a203: Gambar dengan koordinat disimpan di data_output\data_a203_annotated.jpg
# 🧾 data_a203: Hasil scan bersih disimpan di data_output\data_a203_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a204
# ✅ data_a205: Gambar dengan koordinat disimpan di data_output\data_a205_annotated.jpg
# 🧾 data_a205: Hasil scan bersih disimpan di data_output\data_a205_scan.jpg
#
# ✅ data_a206: Gambar dengan koordinat disimpan di data_output\data_a206_annotated.jpg
# 🧾 data_a206: Hasil scan bersih disimpan di data_output\data_a206_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a207
# ✅ data_a208: Gambar dengan koordinat disimpan di data_output\data_a208_annotated.jpg
# 🧾 data_a208: Hasil scan bersih disimpan di data_output\data_a208_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a209
# ✅ data_a21: Gambar dengan koordinat disimpan di data_output\data_a21_annotated.jpg
# 🧾 data_a21: Hasil scan bersih disimpan di data_output\data_a21_scan.jpg
#
# ✅ data_a210: Gambar dengan koordinat disimpan di data_output\data_a210_annotated.jpg
# 🧾 data_a210: Hasil scan bersih disimpan di data_output\data_a210_scan.jpg
#
# ✅ data_a211: Gambar dengan koordinat disimpan di data_output\data_a211_annotated.jpg
# 🧾 data_a211: Hasil scan bersih disimpan di data_output\data_a211_scan.jpg
#
# ✅ data_a212: Gambar dengan koordinat disimpan di data_output\data_a212_annotated.jpg
# 🧾 data_a212: Hasil scan bersih disimpan di data_output\data_a212_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a213
# ✅ data_a214: Gambar dengan koordinat disimpan di data_output\data_a214_annotated.jpg
# 🧾 data_a214: Hasil scan bersih disimpan di data_output\data_a214_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a215
# ✅ data_a216: Gambar dengan koordinat disimpan di data_output\data_a216_annotated.jpg
# 🧾 data_a216: Hasil scan bersih disimpan di data_output\data_a216_scan.jpg
#
# ✅ data_a217: Gambar dengan koordinat disimpan di data_output\data_a217_annotated.jpg
# 🧾 data_a217: Hasil scan bersih disimpan di data_output\data_a217_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a218
# ❌ Dokumen tidak ditemukan pada data_a219
# ✅ data_a22: Gambar dengan koordinat disimpan di data_output\data_a22_annotated.jpg
# 🧾 data_a22: Hasil scan bersih disimpan di data_output\data_a22_scan.jpg
#
# ✅ data_a220: Gambar dengan koordinat disimpan di data_output\data_a220_annotated.jpg
# 🧾 data_a220: Hasil scan bersih disimpan di data_output\data_a220_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a221
# ❌ Dokumen tidak ditemukan pada data_a222
# ✅ data_a223: Gambar dengan koordinat disimpan di data_output\data_a223_annotated.jpg
# 🧾 data_a223: Hasil scan bersih disimpan di data_output\data_a223_scan.jpg
#
# ✅ data_a224: Gambar dengan koordinat disimpan di data_output\data_a224_annotated.jpg
# 🧾 data_a224: Hasil scan bersih disimpan di data_output\data_a224_scan.jpg
#
# ✅ data_a225: Gambar dengan koordinat disimpan di data_output\data_a225_annotated.jpg
# 🧾 data_a225: Hasil scan bersih disimpan di data_output\data_a225_scan.jpg
#
# ✅ data_a226: Gambar dengan koordinat disimpan di data_output\data_a226_annotated.jpg
# 🧾 data_a226: Hasil scan bersih disimpan di data_output\data_a226_scan.jpg
#
# ✅ data_a227: Gambar dengan koordinat disimpan di data_output\data_a227_annotated.jpg
# 🧾 data_a227: Hasil scan bersih disimpan di data_output\data_a227_scan.jpg
#
# ✅ data_a228: Gambar dengan koordinat disimpan di data_output\data_a228_annotated.jpg
# 🧾 data_a228: Hasil scan bersih disimpan di data_output\data_a228_scan.jpg
#
# ✅ data_a229: Gambar dengan koordinat disimpan di data_output\data_a229_annotated.jpg
# 🧾 data_a229: Hasil scan bersih disimpan di data_output\data_a229_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a23
# ❌ Dokumen tidak ditemukan pada data_a230
# ❌ Dokumen tidak ditemukan pada data_a231
# ✅ data_a232: Gambar dengan koordinat disimpan di data_output\data_a232_annotated.jpg
# 🧾 data_a232: Hasil scan bersih disimpan di data_output\data_a232_scan.jpg
#
# ✅ data_a233: Gambar dengan koordinat disimpan di data_output\data_a233_annotated.jpg
# 🧾 data_a233: Hasil scan bersih disimpan di data_output\data_a233_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a234
# ❌ Dokumen tidak ditemukan pada data_a235
# ✅ data_a236: Gambar dengan koordinat disimpan di data_output\data_a236_annotated.jpg
# 🧾 data_a236: Hasil scan bersih disimpan di data_output\data_a236_scan.jpg
#
# ✅ data_a237: Gambar dengan koordinat disimpan di data_output\data_a237_annotated.jpg
# 🧾 data_a237: Hasil scan bersih disimpan di data_output\data_a237_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a238
# ✅ data_a239: Gambar dengan koordinat disimpan di data_output\data_a239_annotated.jpg
# 🧾 data_a239: Hasil scan bersih disimpan di data_output\data_a239_scan.jpg
#
# ✅ data_a24: Gambar dengan koordinat disimpan di data_output\data_a24_annotated.jpg
# 🧾 data_a24: Hasil scan bersih disimpan di data_output\data_a24_scan.jpg
#
# ✅ data_a240: Gambar dengan koordinat disimpan di data_output\data_a240_annotated.jpg
# 🧾 data_a240: Hasil scan bersih disimpan di data_output\data_a240_scan.jpg
#
# ✅ data_a241: Gambar dengan koordinat disimpan di data_output\data_a241_annotated.jpg
# 🧾 data_a241: Hasil scan bersih disimpan di data_output\data_a241_scan.jpg
#
# ✅ data_a242: Gambar dengan koordinat disimpan di data_output\data_a242_annotated.jpg
# 🧾 data_a242: Hasil scan bersih disimpan di data_output\data_a242_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a243
# ✅ data_a244: Gambar dengan koordinat disimpan di data_output\data_a244_annotated.jpg
# 🧾 data_a244: Hasil scan bersih disimpan di data_output\data_a244_scan.jpg
#
# ✅ data_a245: Gambar dengan koordinat disimpan di data_output\data_a245_annotated.jpg
# 🧾 data_a245: Hasil scan bersih disimpan di data_output\data_a245_scan.jpg
#
# ✅ data_a246: Gambar dengan koordinat disimpan di data_output\data_a246_annotated.jpg
# 🧾 data_a246: Hasil scan bersih disimpan di data_output\data_a246_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a247
# ✅ data_a248: Gambar dengan koordinat disimpan di data_output\data_a248_annotated.jpg
# 🧾 data_a248: Hasil scan bersih disimpan di data_output\data_a248_scan.jpg
#
# ✅ data_a249: Gambar dengan koordinat disimpan di data_output\data_a249_annotated.jpg
# 🧾 data_a249: Hasil scan bersih disimpan di data_output\data_a249_scan.jpg
#
# ✅ data_a25: Gambar dengan koordinat disimpan di data_output\data_a25_annotated.jpg
# 🧾 data_a25: Hasil scan bersih disimpan di data_output\data_a25_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a250
# ❌ Dokumen tidak ditemukan pada data_a251
# ❌ Dokumen tidak ditemukan pada data_a252
# ❌ Dokumen tidak ditemukan pada data_a253
# ❌ Dokumen tidak ditemukan pada data_a254
# ✅ data_a255: Gambar dengan koordinat disimpan di data_output\data_a255_annotated.jpg
# 🧾 data_a255: Hasil scan bersih disimpan di data_output\data_a255_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a256
# ✅ data_a257: Gambar dengan koordinat disimpan di data_output\data_a257_annotated.jpg
# 🧾 data_a257: Hasil scan bersih disimpan di data_output\data_a257_scan.jpg
#
# ✅ data_a258: Gambar dengan koordinat disimpan di data_output\data_a258_annotated.jpg
# 🧾 data_a258: Hasil scan bersih disimpan di data_output\data_a258_scan.jpg
#
# ✅ data_a259: Gambar dengan koordinat disimpan di data_output\data_a259_annotated.jpg
# 🧾 data_a259: Hasil scan bersih disimpan di data_output\data_a259_scan.jpg
#
# ✅ data_a26: Gambar dengan koordinat disimpan di data_output\data_a26_annotated.jpg
# 🧾 data_a26: Hasil scan bersih disimpan di data_output\data_a26_scan.jpg
#
# ✅ data_a260: Gambar dengan koordinat disimpan di data_output\data_a260_annotated.jpg
# 🧾 data_a260: Hasil scan bersih disimpan di data_output\data_a260_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a261
# ❌ Dokumen tidak ditemukan pada data_a262
# ✅ data_a263: Gambar dengan koordinat disimpan di data_output\data_a263_annotated.jpg
# 🧾 data_a263: Hasil scan bersih disimpan di data_output\data_a263_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a264
# ✅ data_a265: Gambar dengan koordinat disimpan di data_output\data_a265_annotated.jpg
# 🧾 data_a265: Hasil scan bersih disimpan di data_output\data_a265_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a266
# ❌ Dokumen tidak ditemukan pada data_a267
# ✅ data_a268: Gambar dengan koordinat disimpan di data_output\data_a268_annotated.jpg
# 🧾 data_a268: Hasil scan bersih disimpan di data_output\data_a268_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a269
# ✅ data_a27: Gambar dengan koordinat disimpan di data_output\data_a27_annotated.jpg
# 🧾 data_a27: Hasil scan bersih disimpan di data_output\data_a27_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a270
# ✅ data_a271: Gambar dengan koordinat disimpan di data_output\data_a271_annotated.jpg
# 🧾 data_a271: Hasil scan bersih disimpan di data_output\data_a271_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a272
# ✅ data_a273: Gambar dengan koordinat disimpan di data_output\data_a273_annotated.jpg
# 🧾 data_a273: Hasil scan bersih disimpan di data_output\data_a273_scan.jpg
#
# ✅ data_a274: Gambar dengan koordinat disimpan di data_output\data_a274_annotated.jpg
# 🧾 data_a274: Hasil scan bersih disimpan di data_output\data_a274_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a275
# ❌ Dokumen tidak ditemukan pada data_a276
# ❌ Dokumen tidak ditemukan pada data_a277
# ❌ Dokumen tidak ditemukan pada data_a278
# ❌ Dokumen tidak ditemukan pada data_a279
# ✅ data_a28: Gambar dengan koordinat disimpan di data_output\data_a28_annotated.jpg
# 🧾 data_a28: Hasil scan bersih disimpan di data_output\data_a28_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a280
# ❌ Dokumen tidak ditemukan pada data_a281
# ❌ Dokumen tidak ditemukan pada data_a282
# ✅ data_a283: Gambar dengan koordinat disimpan di data_output\data_a283_annotated.jpg
# 🧾 data_a283: Hasil scan bersih disimpan di data_output\data_a283_scan.jpg
#
# ✅ data_a284: Gambar dengan koordinat disimpan di data_output\data_a284_annotated.jpg
# 🧾 data_a284: Hasil scan bersih disimpan di data_output\data_a284_scan.jpg
#
# ✅ data_a285: Gambar dengan koordinat disimpan di data_output\data_a285_annotated.jpg
# 🧾 data_a285: Hasil scan bersih disimpan di data_output\data_a285_scan.jpg
#
# ✅ data_a286: Gambar dengan koordinat disimpan di data_output\data_a286_annotated.jpg
# 🧾 data_a286: Hasil scan bersih disimpan di data_output\data_a286_scan.jpg
#
# ✅ data_a287: Gambar dengan koordinat disimpan di data_output\data_a287_annotated.jpg
# 🧾 data_a287: Hasil scan bersih disimpan di data_output\data_a287_scan.jpg
#
# ✅ data_a288: Gambar dengan koordinat disimpan di data_output\data_a288_annotated.jpg
# 🧾 data_a288: Hasil scan bersih disimpan di data_output\data_a288_scan.jpg
#
# ✅ data_a289: Gambar dengan koordinat disimpan di data_output\data_a289_annotated.jpg
# 🧾 data_a289: Hasil scan bersih disimpan di data_output\data_a289_scan.jpg
#
# ✅ data_a29: Gambar dengan koordinat disimpan di data_output\data_a29_annotated.jpg
# 🧾 data_a29: Hasil scan bersih disimpan di data_output\data_a29_scan.jpg
#
# ✅ data_a290: Gambar dengan koordinat disimpan di data_output\data_a290_annotated.jpg
# 🧾 data_a290: Hasil scan bersih disimpan di data_output\data_a290_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a291
# ❌ Dokumen tidak ditemukan pada data_a292
# ❌ Dokumen tidak ditemukan pada data_a293
# ✅ data_a294: Gambar dengan koordinat disimpan di data_output\data_a294_annotated.jpg
# 🧾 data_a294: Hasil scan bersih disimpan di data_output\data_a294_scan.jpg
#
# ✅ data_a295: Gambar dengan koordinat disimpan di data_output\data_a295_annotated.jpg
# 🧾 data_a295: Hasil scan bersih disimpan di data_output\data_a295_scan.jpg
#
# ✅ data_a296: Gambar dengan koordinat disimpan di data_output\data_a296_annotated.jpg
# 🧾 data_a296: Hasil scan bersih disimpan di data_output\data_a296_scan.jpg
#
# ✅ data_a297: Gambar dengan koordinat disimpan di data_output\data_a297_annotated.jpg
# 🧾 data_a297: Hasil scan bersih disimpan di data_output\data_a297_scan.jpg
#
# ✅ data_a298: Gambar dengan koordinat disimpan di data_output\data_a298_annotated.jpg
# 🧾 data_a298: Hasil scan bersih disimpan di data_output\data_a298_scan.jpg
#
# ✅ data_a299: Gambar dengan koordinat disimpan di data_output\data_a299_annotated.jpg
# 🧾 data_a299: Hasil scan bersih disimpan di data_output\data_a299_scan.jpg
#
# ✅ data_a3: Gambar dengan koordinat disimpan di data_output\data_a3_annotated.jpg
# 🧾 data_a3: Hasil scan bersih disimpan di data_output\data_a3_scan.jpg
#
# ✅ data_a30: Gambar dengan koordinat disimpan di data_output\data_a30_annotated.jpg
# 🧾 data_a30: Hasil scan bersih disimpan di data_output\data_a30_scan.jpg
#
# ✅ data_a300: Gambar dengan koordinat disimpan di data_output\data_a300_annotated.jpg
# 🧾 data_a300: Hasil scan bersih disimpan di data_output\data_a300_scan.jpg
#
# ✅ data_a301: Gambar dengan koordinat disimpan di data_output\data_a301_annotated.jpg
# 🧾 data_a301: Hasil scan bersih disimpan di data_output\data_a301_scan.jpg
#
# ✅ data_a302: Gambar dengan koordinat disimpan di data_output\data_a302_annotated.jpg
# 🧾 data_a302: Hasil scan bersih disimpan di data_output\data_a302_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a303
# ✅ data_a304: Gambar dengan koordinat disimpan di data_output\data_a304_annotated.jpg
# 🧾 data_a304: Hasil scan bersih disimpan di data_output\data_a304_scan.jpg
#
# ✅ data_a305: Gambar dengan koordinat disimpan di data_output\data_a305_annotated.jpg
# 🧾 data_a305: Hasil scan bersih disimpan di data_output\data_a305_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a306
# ✅ data_a307: Gambar dengan koordinat disimpan di data_output\data_a307_annotated.jpg
# 🧾 data_a307: Hasil scan bersih disimpan di data_output\data_a307_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a308
# ✅ data_a309: Gambar dengan koordinat disimpan di data_output\data_a309_annotated.jpg
# 🧾 data_a309: Hasil scan bersih disimpan di data_output\data_a309_scan.jpg
#
# ✅ data_a31: Gambar dengan koordinat disimpan di data_output\data_a31_annotated.jpg
# 🧾 data_a31: Hasil scan bersih disimpan di data_output\data_a31_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a310
# ❌ Dokumen tidak ditemukan pada data_a311
# ✅ data_a312: Gambar dengan koordinat disimpan di data_output\data_a312_annotated.jpg
# 🧾 data_a312: Hasil scan bersih disimpan di data_output\data_a312_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a313
# ✅ data_a314: Gambar dengan koordinat disimpan di data_output\data_a314_annotated.jpg
# 🧾 data_a314: Hasil scan bersih disimpan di data_output\data_a314_scan.jpg
#
# ✅ data_a315: Gambar dengan koordinat disimpan di data_output\data_a315_annotated.jpg
# 🧾 data_a315: Hasil scan bersih disimpan di data_output\data_a315_scan.jpg
#
# ✅ data_a316: Gambar dengan koordinat disimpan di data_output\data_a316_annotated.jpg
# 🧾 data_a316: Hasil scan bersih disimpan di data_output\data_a316_scan.jpg
#
# ✅ data_a317: Gambar dengan koordinat disimpan di data_output\data_a317_annotated.jpg
# 🧾 data_a317: Hasil scan bersih disimpan di data_output\data_a317_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a318
# ✅ data_a319: Gambar dengan koordinat disimpan di data_output\data_a319_annotated.jpg
# 🧾 data_a319: Hasil scan bersih disimpan di data_output\data_a319_scan.jpg
#
# ✅ data_a32: Gambar dengan koordinat disimpan di data_output\data_a32_annotated.jpg
# 🧾 data_a32: Hasil scan bersih disimpan di data_output\data_a32_scan.jpg
#
# ✅ data_a320: Gambar dengan koordinat disimpan di data_output\data_a320_annotated.jpg
# 🧾 data_a320: Hasil scan bersih disimpan di data_output\data_a320_scan.jpg
#
# ✅ data_a321: Gambar dengan koordinat disimpan di data_output\data_a321_annotated.jpg
# 🧾 data_a321: Hasil scan bersih disimpan di data_output\data_a321_scan.jpg
#
# ✅ data_a322: Gambar dengan koordinat disimpan di data_output\data_a322_annotated.jpg
# 🧾 data_a322: Hasil scan bersih disimpan di data_output\data_a322_scan.jpg
#
# ✅ data_a323: Gambar dengan koordinat disimpan di data_output\data_a323_annotated.jpg
# 🧾 data_a323: Hasil scan bersih disimpan di data_output\data_a323_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a324
# ❌ Dokumen tidak ditemukan pada data_a325
# ✅ data_a326: Gambar dengan koordinat disimpan di data_output\data_a326_annotated.jpg
# 🧾 data_a326: Hasil scan bersih disimpan di data_output\data_a326_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a327
# ❌ Dokumen tidak ditemukan pada data_a328
# ✅ data_a329: Gambar dengan koordinat disimpan di data_output\data_a329_annotated.jpg
# 🧾 data_a329: Hasil scan bersih disimpan di data_output\data_a329_scan.jpg
#
# ✅ data_a33: Gambar dengan koordinat disimpan di data_output\data_a33_annotated.jpg
# 🧾 data_a33: Hasil scan bersih disimpan di data_output\data_a33_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a330
# ✅ data_a331: Gambar dengan koordinat disimpan di data_output\data_a331_annotated.jpg
# 🧾 data_a331: Hasil scan bersih disimpan di data_output\data_a331_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a332
# ❌ Dokumen tidak ditemukan pada data_a333
# ❌ Dokumen tidak ditemukan pada data_a334
# ❌ Dokumen tidak ditemukan pada data_a335
# ❌ Dokumen tidak ditemukan pada data_a336
# ❌ Dokumen tidak ditemukan pada data_a337
# ❌ Dokumen tidak ditemukan pada data_a338
# ❌ Dokumen tidak ditemukan pada data_a339
# ✅ data_a34: Gambar dengan koordinat disimpan di data_output\data_a34_annotated.jpg
# 🧾 data_a34: Hasil scan bersih disimpan di data_output\data_a34_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a340
# ❌ Dokumen tidak ditemukan pada data_a341
# ✅ data_a342: Gambar dengan koordinat disimpan di data_output\data_a342_annotated.jpg
# 🧾 data_a342: Hasil scan bersih disimpan di data_output\data_a342_scan.jpg
#
# ✅ data_a343: Gambar dengan koordinat disimpan di data_output\data_a343_annotated.jpg
# 🧾 data_a343: Hasil scan bersih disimpan di data_output\data_a343_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a344
# ❌ Dokumen tidak ditemukan pada data_a345
# ❌ Dokumen tidak ditemukan pada data_a346
# ❌ Dokumen tidak ditemukan pada data_a347
# ❌ Dokumen tidak ditemukan pada data_a348
# ❌ Dokumen tidak ditemukan pada data_a349
# ✅ data_a35: Gambar dengan koordinat disimpan di data_output\data_a35_annotated.jpg
# 🧾 data_a35: Hasil scan bersih disimpan di data_output\data_a35_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a350
# ❌ Dokumen tidak ditemukan pada data_a351
# ❌ Dokumen tidak ditemukan pada data_a352
# ✅ data_a353: Gambar dengan koordinat disimpan di data_output\data_a353_annotated.jpg
# 🧾 data_a353: Hasil scan bersih disimpan di data_output\data_a353_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a354
# ❌ Dokumen tidak ditemukan pada data_a355
# ❌ Dokumen tidak ditemukan pada data_a356
# ❌ Dokumen tidak ditemukan pada data_a357
# ❌ Dokumen tidak ditemukan pada data_a358
# ❌ Dokumen tidak ditemukan pada data_a359
# ❌ Dokumen tidak ditemukan pada data_a36
# ✅ data_a360: Gambar dengan koordinat disimpan di data_output\data_a360_annotated.jpg
# 🧾 data_a360: Hasil scan bersih disimpan di data_output\data_a360_scan.jpg
#
# ✅ data_a361: Gambar dengan koordinat disimpan di data_output\data_a361_annotated.jpg
# 🧾 data_a361: Hasil scan bersih disimpan di data_output\data_a361_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a362
# ❌ Dokumen tidak ditemukan pada data_a363
# ✅ data_a364: Gambar dengan koordinat disimpan di data_output\data_a364_annotated.jpg
# 🧾 data_a364: Hasil scan bersih disimpan di data_output\data_a364_scan.jpg
#
# ✅ data_a365: Gambar dengan koordinat disimpan di data_output\data_a365_annotated.jpg
# 🧾 data_a365: Hasil scan bersih disimpan di data_output\data_a365_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a366
# ❌ Dokumen tidak ditemukan pada data_a367
# ✅ data_a368: Gambar dengan koordinat disimpan di data_output\data_a368_annotated.jpg
# 🧾 data_a368: Hasil scan bersih disimpan di data_output\data_a368_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a369
# ✅ data_a37: Gambar dengan koordinat disimpan di data_output\data_a37_annotated.jpg
# 🧾 data_a37: Hasil scan bersih disimpan di data_output\data_a37_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a370
# ✅ data_a371: Gambar dengan koordinat disimpan di data_output\data_a371_annotated.jpg
# 🧾 data_a371: Hasil scan bersih disimpan di data_output\data_a371_scan.jpg
#
# ✅ data_a372: Gambar dengan koordinat disimpan di data_output\data_a372_annotated.jpg
# 🧾 data_a372: Hasil scan bersih disimpan di data_output\data_a372_scan.jpg
#
# ✅ data_a373: Gambar dengan koordinat disimpan di data_output\data_a373_annotated.jpg
# 🧾 data_a373: Hasil scan bersih disimpan di data_output\data_a373_scan.jpg
#
# ✅ data_a374: Gambar dengan koordinat disimpan di data_output\data_a374_annotated.jpg
# 🧾 data_a374: Hasil scan bersih disimpan di data_output\data_a374_scan.jpg
#
# ✅ data_a375: Gambar dengan koordinat disimpan di data_output\data_a375_annotated.jpg
# 🧾 data_a375: Hasil scan bersih disimpan di data_output\data_a375_scan.jpg
#
# ✅ data_a376: Gambar dengan koordinat disimpan di data_output\data_a376_annotated.jpg
# 🧾 data_a376: Hasil scan bersih disimpan di data_output\data_a376_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a377
# ✅ data_a378: Gambar dengan koordinat disimpan di data_output\data_a378_annotated.jpg
# 🧾 data_a378: Hasil scan bersih disimpan di data_output\data_a378_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a379
# ❌ Dokumen tidak ditemukan pada data_a38
# ✅ data_a380: Gambar dengan koordinat disimpan di data_output\data_a380_annotated.jpg
# 🧾 data_a380: Hasil scan bersih disimpan di data_output\data_a380_scan.jpg
#
# ✅ data_a381: Gambar dengan koordinat disimpan di data_output\data_a381_annotated.jpg
# 🧾 data_a381: Hasil scan bersih disimpan di data_output\data_a381_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a382
# ✅ data_a383: Gambar dengan koordinat disimpan di data_output\data_a383_annotated.jpg
# 🧾 data_a383: Hasil scan bersih disimpan di data_output\data_a383_scan.jpg
#
# ✅ data_a384: Gambar dengan koordinat disimpan di data_output\data_a384_annotated.jpg
# 🧾 data_a384: Hasil scan bersih disimpan di data_output\data_a384_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a385
# ❌ Dokumen tidak ditemukan pada data_a386
# ❌ Dokumen tidak ditemukan pada data_a387
# ✅ data_a388: Gambar dengan koordinat disimpan di data_output\data_a388_annotated.jpg
# 🧾 data_a388: Hasil scan bersih disimpan di data_output\data_a388_scan.jpg
#
# ✅ data_a389: Gambar dengan koordinat disimpan di data_output\data_a389_annotated.jpg
# 🧾 data_a389: Hasil scan bersih disimpan di data_output\data_a389_scan.jpg
#
# ✅ data_a39: Gambar dengan koordinat disimpan di data_output\data_a39_annotated.jpg
# 🧾 data_a39: Hasil scan bersih disimpan di data_output\data_a39_scan.jpg
#
# ✅ data_a390: Gambar dengan koordinat disimpan di data_output\data_a390_annotated.jpg
# 🧾 data_a390: Hasil scan bersih disimpan di data_output\data_a390_scan.jpg
#
# ✅ data_a391: Gambar dengan koordinat disimpan di data_output\data_a391_annotated.jpg
# 🧾 data_a391: Hasil scan bersih disimpan di data_output\data_a391_scan.jpg
#
# ✅ data_a392: Gambar dengan koordinat disimpan di data_output\data_a392_annotated.jpg
# 🧾 data_a392: Hasil scan bersih disimpan di data_output\data_a392_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a393
# ❌ Dokumen tidak ditemukan pada data_a394
# ✅ data_a395: Gambar dengan koordinat disimpan di data_output\data_a395_annotated.jpg
# 🧾 data_a395: Hasil scan bersih disimpan di data_output\data_a395_scan.jpg
#
# ✅ data_a396: Gambar dengan koordinat disimpan di data_output\data_a396_annotated.jpg
# 🧾 data_a396: Hasil scan bersih disimpan di data_output\data_a396_scan.jpg
#
# ✅ data_a397: Gambar dengan koordinat disimpan di data_output\data_a397_annotated.jpg
# 🧾 data_a397: Hasil scan bersih disimpan di data_output\data_a397_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a398
# ✅ data_a399: Gambar dengan koordinat disimpan di data_output\data_a399_annotated.jpg
# 🧾 data_a399: Hasil scan bersih disimpan di data_output\data_a399_scan.jpg
#
# ✅ data_a4: Gambar dengan koordinat disimpan di data_output\data_a4_annotated.jpg
# 🧾 data_a4: Hasil scan bersih disimpan di data_output\data_a4_scan.jpg
#
# ✅ data_a40: Gambar dengan koordinat disimpan di data_output\data_a40_annotated.jpg
# 🧾 data_a40: Hasil scan bersih disimpan di data_output\data_a40_scan.jpg
#
# ✅ data_a400: Gambar dengan koordinat disimpan di data_output\data_a400_annotated.jpg
# 🧾 data_a400: Hasil scan bersih disimpan di data_output\data_a400_scan.jpg
#
# ✅ data_a401: Gambar dengan koordinat disimpan di data_output\data_a401_annotated.jpg
# 🧾 data_a401: Hasil scan bersih disimpan di data_output\data_a401_scan.jpg
#
# ✅ data_a41: Gambar dengan koordinat disimpan di data_output\data_a41_annotated.jpg
# 🧾 data_a41: Hasil scan bersih disimpan di data_output\data_a41_scan.jpg
#
# ✅ data_a42: Gambar dengan koordinat disimpan di data_output\data_a42_annotated.jpg
# 🧾 data_a42: Hasil scan bersih disimpan di data_output\data_a42_scan.jpg
#
# ✅ data_a43: Gambar dengan koordinat disimpan di data_output\data_a43_annotated.jpg
# 🧾 data_a43: Hasil scan bersih disimpan di data_output\data_a43_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a44
# ❌ Dokumen tidak ditemukan pada data_a45
# ❌ Dokumen tidak ditemukan pada data_a46
# ✅ data_a47: Gambar dengan koordinat disimpan di data_output\data_a47_annotated.jpg
# 🧾 data_a47: Hasil scan bersih disimpan di data_output\data_a47_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a48
# ✅ data_a49: Gambar dengan koordinat disimpan di data_output\data_a49_annotated.jpg
# 🧾 data_a49: Hasil scan bersih disimpan di data_output\data_a49_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a5
# ❌ Dokumen tidak ditemukan pada data_a50
# ✅ data_a51: Gambar dengan koordinat disimpan di data_output\data_a51_annotated.jpg
# 🧾 data_a51: Hasil scan bersih disimpan di data_output\data_a51_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a52
# ✅ data_a53: Gambar dengan koordinat disimpan di data_output\data_a53_annotated.jpg
# 🧾 data_a53: Hasil scan bersih disimpan di data_output\data_a53_scan.jpg
#
# ✅ data_a54: Gambar dengan koordinat disimpan di data_output\data_a54_annotated.jpg
# 🧾 data_a54: Hasil scan bersih disimpan di data_output\data_a54_scan.jpg
#
# ✅ data_a55: Gambar dengan koordinat disimpan di data_output\data_a55_annotated.jpg
# 🧾 data_a55: Hasil scan bersih disimpan di data_output\data_a55_scan.jpg
#
# ✅ data_a56: Gambar dengan koordinat disimpan di data_output\data_a56_annotated.jpg
# 🧾 data_a56: Hasil scan bersih disimpan di data_output\data_a56_scan.jpg
#
# ✅ data_a57: Gambar dengan koordinat disimpan di data_output\data_a57_annotated.jpg
# 🧾 data_a57: Hasil scan bersih disimpan di data_output\data_a57_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a58
# ✅ data_a59: Gambar dengan koordinat disimpan di data_output\data_a59_annotated.jpg
# 🧾 data_a59: Hasil scan bersih disimpan di data_output\data_a59_scan.jpg
#
# ✅ data_a6: Gambar dengan koordinat disimpan di data_output\data_a6_annotated.jpg
# 🧾 data_a6: Hasil scan bersih disimpan di data_output\data_a6_scan.jpg
#
# ✅ data_a60: Gambar dengan koordinat disimpan di data_output\data_a60_annotated.jpg
# 🧾 data_a60: Hasil scan bersih disimpan di data_output\data_a60_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a61
# ✅ data_a62: Gambar dengan koordinat disimpan di data_output\data_a62_annotated.jpg
# 🧾 data_a62: Hasil scan bersih disimpan di data_output\data_a62_scan.jpg
#
# ✅ data_a63: Gambar dengan koordinat disimpan di data_output\data_a63_annotated.jpg
# 🧾 data_a63: Hasil scan bersih disimpan di data_output\data_a63_scan.jpg
#
# ✅ data_a64: Gambar dengan koordinat disimpan di data_output\data_a64_annotated.jpg
# 🧾 data_a64: Hasil scan bersih disimpan di data_output\data_a64_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a65
# ❌ Dokumen tidak ditemukan pada data_a66
# ✅ data_a67: Gambar dengan koordinat disimpan di data_output\data_a67_annotated.jpg
# 🧾 data_a67: Hasil scan bersih disimpan di data_output\data_a67_scan.jpg
#
# ✅ data_a68: Gambar dengan koordinat disimpan di data_output\data_a68_annotated.jpg
# 🧾 data_a68: Hasil scan bersih disimpan di data_output\data_a68_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a69
# ✅ data_a7: Gambar dengan koordinat disimpan di data_output\data_a7_annotated.jpg
# 🧾 data_a7: Hasil scan bersih disimpan di data_output\data_a7_scan.jpg
#
# ✅ data_a70: Gambar dengan koordinat disimpan di data_output\data_a70_annotated.jpg
# 🧾 data_a70: Hasil scan bersih disimpan di data_output\data_a70_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a71
# ❌ Dokumen tidak ditemukan pada data_a72
# ❌ Dokumen tidak ditemukan pada data_a73
# ✅ data_a74: Gambar dengan koordinat disimpan di data_output\data_a74_annotated.jpg
# 🧾 data_a74: Hasil scan bersih disimpan di data_output\data_a74_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a75
# ❌ Dokumen tidak ditemukan pada data_a76
# ❌ Dokumen tidak ditemukan pada data_a77
# ❌ Dokumen tidak ditemukan pada data_a78
# ❌ Dokumen tidak ditemukan pada data_a79
# ❌ Dokumen tidak ditemukan pada data_a8
# ❌ Dokumen tidak ditemukan pada data_a80
# ❌ Dokumen tidak ditemukan pada data_a81
# ❌ Dokumen tidak ditemukan pada data_a82
# ✅ data_a83: Gambar dengan koordinat disimpan di data_output\data_a83_annotated.jpg
# 🧾 data_a83: Hasil scan bersih disimpan di data_output\data_a83_scan.jpg
#
# ✅ data_a84: Gambar dengan koordinat disimpan di data_output\data_a84_annotated.jpg
# 🧾 data_a84: Hasil scan bersih disimpan di data_output\data_a84_scan.jpg
#
# ✅ data_a85: Gambar dengan koordinat disimpan di data_output\data_a85_annotated.jpg
# 🧾 data_a85: Hasil scan bersih disimpan di data_output\data_a85_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a86
# ❌ Dokumen tidak ditemukan pada data_a87
# ❌ Dokumen tidak ditemukan pada data_a88
# ✅ data_a89: Gambar dengan koordinat disimpan di data_output\data_a89_annotated.jpg
# 🧾 data_a89: Hasil scan bersih disimpan di data_output\data_a89_scan.jpg
#
# ✅ data_a9: Gambar dengan koordinat disimpan di data_output\data_a9_annotated.jpg
# 🧾 data_a9: Hasil scan bersih disimpan di data_output\data_a9_scan.jpg
#
# ✅ data_a90: Gambar dengan koordinat disimpan di data_output\data_a90_annotated.jpg
# 🧾 data_a90: Hasil scan bersih disimpan di data_output\data_a90_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a91
# ❌ Dokumen tidak ditemukan pada data_a92
# ❌ Dokumen tidak ditemukan pada data_a93
# ✅ data_a94: Gambar dengan koordinat disimpan di data_output\data_a94_annotated.jpg
# 🧾 data_a94: Hasil scan bersih disimpan di data_output\data_a94_scan.jpg
#
# ✅ data_a95: Gambar dengan koordinat disimpan di data_output\data_a95_annotated.jpg
# 🧾 data_a95: Hasil scan bersih disimpan di data_output\data_a95_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a96
# ✅ data_a97: Gambar dengan koordinat disimpan di data_output\data_a97_annotated.jpg
# 🧾 data_a97: Hasil scan bersih disimpan di data_output\data_a97_scan.jpg
#
# ❌ Dokumen tidak ditemukan pada data_a98
# ❌ Dokumen tidak ditemukan pada data_a99
# 🚀 Semua gambar selesai diproses!
